# %% [markdown]
# # Metacritic Video Game Reviews Scraper
#
# *Based on the idea (and a bit of code) from the repository [projectGames](https://github.com/BrunoBVR/projectGames) (2020), but rewritten to account for the current structure of the Metacritic website and to extract the specific data I wanted to collect.*
#
# Using Metacritic’s own [search tool](https://www.metacritic.com/browse/games/score/metascore/all/all/filtered?sort=desc), I scraped data to build a large dataframe containing scores, release dates, genres, developers, and publishers of all games across all platforms (at least the games that are in Metacritic). This code generates 2 datasets: the raw one, with nulls and tbd as scores (basically unreviewed games), in case you want absolutely all the data; and the clean one, with all the rows with missing data removed.
#
# Features:
# - httpx + asyncio with concurrency limit.
# - Extraction of listings and details (JSON-LD + platforms + scores).
# - Incremental saving per page in `pages/`.
# - Consolidated DataFrame in `metacritic_dataset.csv`.
#
# **Data scraped on October 7, 2025.**

# %% [markdown]
# ## Initial requirements and parameters

# %%
# %pip install -r requirements.txt
# Out:
# Collecting httpx (from -r requirements.txt (line 1))
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting beautifulsoup4 (from -r requirements.txt (line 2))
#   Using cached beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting lxml (from -r requirements.txt (line 3))
#   Using cached lxml-6.0.2-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Collecting pandas (from -r requirements.txt (line 4))
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting anyio (from httpx->-r requirements.txt (line 1))
#   Using cached anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting certifi (from httpx->-r requirements.txt (line 1))
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx->-r requirements.txt (line 1))
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx->-r requirements.txt (line 1))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx->-r requirements.txt (line 1))
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->-r requirements.txt (line 2))
#   Using cached soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4->-r requirements.txt (line 2))
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting numpy>=1.26.0 (from pandas->-r requirements.txt (line 4))
#   Using cached numpy-2.3.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\almacenamiento\documents\dataset metacritic\env\lib\site-packages (from pandas->-r requirements.txt (line 4)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->-r requirements.txt (line 4))
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r requirements.txt (line 4))
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in d:\almacenamiento\documents\dataset metacritic\env\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 4)) (1.17.0)
# Collecting sniffio>=1.1 (from anyio->httpx->-r requirements.txt (line 1))
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Using cached lxml-6.0.2-cp312-cp312-win_amd64.whl (4.0 MB)
# Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached numpy-2.3.3-cp312-cp312-win_amd64.whl (12.8 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached soupsieve-2.8-py3-none-any.whl (36 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached anyio-4.11.0-py3-none-any.whl (109 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: pytz, tzdata, typing-extensions, soupsieve, sniffio, numpy, lxml, idna, h11, certifi, pandas, httpcore, beautifulsoup4, anyio, httpx
# Successfully installed anyio-4.11.0 beautifulsoup4-4.14.2 certifi-2025.10.5 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.10 lxml-6.0.2 numpy-2.3.3 pandas-2.3.3 pytz-2025.2 sniffio-1.3.1 soupsieve-2.8 typing-extensions-4.15.0 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Asynchronous Metacritic scraper (pages range configurable)
import asyncio, random, json, time, re
from pathlib import Path
from typing import List, Dict, Any
import httpx
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# Parameters you can adjust within the code:
# - `PAGES`: Total pages of games in the Metacritic Web. There are 580 as of October 2025.
# - `MAX_CONCURRENCY`: Number of workers. Increase/decrease depending on speed vs. blocking risk.
# - `OUTPUT_DIR`: Path for storing the pages csvs

# %%
BASE_DOMAIN = "https://www.metacritic.com"
LIST_URL = ("https://www.metacritic.com/browse/game/?releaseYearMin=1958&"
            "releaseYearMax=2025&page={page}")   # List of all games

PAGES = 580  # adjust for more pages
MAX_CONCURRENCY = 15
OUTPUT_DIR = Path("pages")
OUTPUT_DIR.mkdir(exist_ok=True)

HEADERS = {
    "User-Agent": ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
                    "(KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"),
    "Accept-Language": "en-US,en;q=0.9"
}

# %% [markdown]
# ## Network helper: concurrency & robust fetching
#
# This cell defines the global semaphore and the `fetch(client, url, ...)` async helper used across the scraper.
#
# - Purpose: perform HTTP GETs with controlled concurrency, retries, exponential backoff and small random jitter to reduce rate-limiting and server load.
# - Key behaviors:
#   - Uses `MAX_CONCURRENCY` via an `asyncio.Semaphore` to limit concurrent requests.
#   - Retries on network errors and on 403/429 responses (rate limits), using `backoff ** attempt` with jitter.
#   - Returns the response body (`str`) on HTTP 200; returns `None` on non-retryable status codes or if all retries fail.
#   - Adds a tiny random sleep after successful requests to avoid immediate bursts.

# %%
sem = asyncio.Semaphore(MAX_CONCURRENCY)

async def fetch(client: httpx.AsyncClient, url: str, retries: int = 3, backoff: float = 1.5) -> str | None:
    for attempt in range(retries):
        try:
            async with sem:
                r = await client.get(url, timeout=25)
        except httpx.RequestError:
            await asyncio.sleep(backoff ** attempt + random.uniform(0, 0.5))
            continue
        if r.status_code == 200:
            # Small jitter to avoid hammering the server
            await asyncio.sleep(random.uniform(0.05, 0.15))
            return r.text
        if r.status_code in (403, 429):
            await asyncio.sleep(backoff ** attempt + random.uniform(0, 1))
            continue
        # Other status codes: do not retry
        return None
    return None

# %% [markdown]
# ## Parsing helpers
#
# ### List-page parser
#
# This cell defines `parse_list_page(html)`.
#
# - Purpose: parse a Metacritic listing/search results page and extract every game entry found on that page, returning a list of dictionaries like `[{"name": <game name>, "url": <absolute url>}, ...]`.
# - Key behavior: selects card elements with the `.c-finderProductCard` selector, extracts the title and anchor, strips leading numeric prefixes from names, converts relative links to absolute using `BASE_DOMAIN`, and skips malformed cards.
# - Note: uses BeautifulSoup (`lxml`) and `re`; selectors may need updating if Metacritic changes its markup.

# %%
def parse_list_page(html: str) -> List[Dict[str, str]]:
    soup = BeautifulSoup(html, 'lxml')
    cards = soup.select('.c-finderProductCard')
    games = []
    for c in cards:
        title = c.select_one('.c-finderProductCard_titleHeading')
        if not title:
            continue
        # Clean numbering at the start if present
        name = re.sub(r'^\d+\.\s*', '', title.get_text(strip=True))
        link = c.select_one('a.c-finderProductCard_container')
        if not link:
            continue
        href = link.get('href')
        if href.startswith('/'):
            href = BASE_DOMAIN + href
        games.append({'name': name, 'url': href})
    return games

# %% [markdown]
# ### JSON-LD and developer extraction
#
# This cell provides two small parsing helpers used by the detail-page processor.
#
# - `extract_json_ld(soup) -> dict` — looks for the page's structured JSON-LD (`<script type="application/ld+json">`) and returns the parsed object. If the script is missing or invalid it returns `{}`.
# - `extract_developer(soup) -> str | None` — extracts the first developer name using the `div.c-gameDetails_Developer ul li` selector and returns `None` if not found.
#
# Notes:
# - Both helpers expect a BeautifulSoup object (`soup`) created with the `lxml` parser.
# - If Metacritic changes markup, update the selectors or add extra fallbacks.

# %%
def extract_json_ld(soup: BeautifulSoup) -> Dict[str, Any]:
    script = soup.find('script', attrs={"type": "application/ld+json"})
    if not script or not script.string:
        return {}
    try:
        return json.loads(script.string)
    except json.JSONDecodeError:
        return {}

def extract_developer(soup: BeautifulSoup) -> str | None:
    dev_li = soup.select_one("div.c-gameDetails_Developer ul li")
    return dev_li.get_text(strip=True) if dev_li else None

# %% [markdown]
# ### Platform scores and user-score extractor
#
# This cell defines helpers that extract platform-specific metascores and user-score pages from a game's detail HTML.
#
# - `extract_platform_scores(soup)`
#   - Input: BeautifulSoup object for a game detail page.
#   - Output: `(metascores, user_urls)` where `metascores` is a list of per-platform metascore strings (or None) and `user_urls` is a list of absolute URLs to the user-review pages for platforms that expose critic/user review pages.
#   - Behavior: finds platform tiles via `.c-gamePlatformsSection_list a.c-gamePlatformTile`, reads the platform name and metascore, normalizes relative hrefs to absolute using `BASE_DOMAIN`, and builds user-review URLs by swapping `critic-reviews` to `user-reviews` when appropriate.
#
# - `extract_user_score(html)`
#   - Input: raw HTML (string) fetched from a user-reviews page.
#   - Output: the user score as a string, or `None` if not found.
#
# Note:
# - If Metacritic's markup changes, update the CSS selectors and the `critic-reviews` -> `user-reviews` heuristic.

# %%
def extract_platform_scores(soup: BeautifulSoup):
    platform_blocks = soup.select('.c-gamePlatformsSection_list a.c-gamePlatformTile')
    platforms, metascores, user_urls = [], [], []
    for a in platform_blocks:
        title_tag = a.find('title')
        platform_name = title_tag.text.strip() if title_tag else None
        score_span = a.select_one('.c-siteReviewScore span')
        meta_val = score_span.text.strip() if score_span else None
        href = a.get('href', '')
        if href.startswith('/'):
            href_full = BASE_DOMAIN + href
        else:
            href_full = href
        if 'critic-reviews/?platform=' in href_full:
            user_urls.append(href_full.replace('critic-reviews', 'user-reviews'))
        platforms.append(platform_name)
        metascores.append(meta_val)
    return metascores, user_urls

def extract_user_score(html: str) -> str | None:
    soup = BeautifulSoup(html, 'lxml')
    container = soup.find(attrs={"data-testid": "score-card-overview"})
    if not container:
        return None
    span = container.select_one('div.c-siteReviewScore span')
    return span.get_text(strip=True) if span else None

# %% [markdown]
# ## Game detail processing
#
# This cell implements `get_game_details(client, game)` which fetches a game's detail page and returns one or more data rows ready to be placed into the dataset.
#
# - Input: `client` (an `httpx.AsyncClient`) and `game` (a dict with `{"name": ..., "url": ...}` produced by `parse_list_page`).
# - Output: A list of dictionaries, one per platform (or a single dict with `platform=None` if platforms aren't found). Each dict contains keys: `name`, `platform`, `release_date`, `metascore`, `user_score`, `developer`, `publisher`, `genre`.
# - Behavior summary:
#   - Fetch detail HTML via `fetch` and parse with BeautifulSoup.
#   - Prefer JSON-LD (`extract_json_ld`) for canonical fields (platforms, release date, publishers, genres).
#   - Extract per-platform metascores and user-review URLs via `extract_platform_scores`, then fetch user pages in parallel and extract user scores with `extract_user_score`.
#   - Assemble rows: if JSON-LD lists platforms, create one row per platform; otherwise produce a single row with `platform=None`.
#
# Edge cases & notes:
# - Missing or invalid JSON-LD will fall back to DOM-extracted values where available.
# - Network failures on user-score pages yield `None` for those scores.
# - This function is intentionally tolerant: it returns an empty list when the main page fetch fails, so the orchestration can continue.

# %%
async def get_game_details(client: httpx.AsyncClient, game: Dict[str, str]) -> List[Dict[str, Any]]:
    html = await fetch(client, game['url'])
    if not html:
        return []
    soup = BeautifulSoup(html, 'lxml')
    data_ld = extract_json_ld(soup)

    metascores, user_urls = extract_platform_scores(soup)

    platforms = data_ld.get("gamePlatform", [])
    release_date = data_ld.get('datePublished')
    publisher_raw = data_ld.get('publisher', [])
    if isinstance(publisher_raw, dict):
        publishers = [publisher_raw.get('name')]
    elif isinstance(publisher_raw, list):
        publishers = [p.get('name') if isinstance(p, dict) else p for p in publisher_raw]
    else:
        publishers = [publisher_raw] if publisher_raw else []

    genres = data_ld.get('genre', [])
    if isinstance(genres, str):
        genres = [genres]

    developer = extract_developer(soup)

    user_scores = []
    if user_urls:
        # Parallelize user score fetches per platform
        tasks = [fetch(client, u) for u in user_urls]
        user_pages = await asyncio.gather(*tasks)
        for page_html in user_pages:
            if not page_html:
                user_scores.append(None)
            else:
                user_scores.append(extract_user_score(page_html))
    else:
        user_scores = [None] * len(platforms)

    rows = []
    if not platforms:
        rows.append({
            'name': game['name'],
            'platform': None,
            'release_date': release_date,
            'metascore': None,
            'user_score': None,
            'developer': developer,
            'publisher': publishers,
            'genre': genres
        })
    else:
        for i, plat in enumerate(platforms):
            rows.append({
                'name': game['name'],
                'platform': plat,
                'release_date': release_date,
                'metascore': metascores[i] if i < len(metascores) else None,
                'user_score': user_scores[i] if i < len(user_scores) else None,
                'developer': developer,
                'publisher': publishers,
                'genre': genres
            })
    return rows

# %% [markdown]
# ## Page orchestration
#
# This cell contains the `process_page(client, page_number)` helper that orchestrates scraping for a single listing page and writes the corresponding csvs.
#
# The code fetches a listing page, then parses the list of games, then fetches details for each game concurrently, and return a pandas.DataFrame with the rows for that page.
#
# Notes:
# - The function is tolerant: a failed listing fetch yields an empty DataFrame so the main orchestrator can continue.
# - Per-page CSVs enable resuming or partial runs without re-fetching already-saved pages.

# %%
async def process_page(client: httpx.AsyncClient, page_number: int) -> pd.DataFrame:
    list_html = await fetch(client, LIST_URL.format(page=page_number))
    if not list_html:
        print(f"[WARN] Failed to fetch listing page {page_number}")
        return pd.DataFrame()
    games = parse_list_page(list_html)
    print(f"Page {page_number}: {len(games)} games detected")

    # Process games concurrently
    tasks = [get_game_details(client, g) for g in games]
    results = await asyncio.gather(*tasks)

    flat_rows = [row for game_rows in results for row in game_rows]
    df_page = pd.DataFrame(flat_rows)

    # Incremental save per page (keep individual page CSVs)
    if not df_page.empty:
        out_file = OUTPUT_DIR / f"games_data-page{page_number}.csv"
        df_page.to_csv(out_file, index=False, encoding='utf-8')
        print(f"Saved page {page_number} -> {len(df_page)} rows")
    else:
        print(f"Page {page_number} has no valid rows")
    return df_page

# %% [markdown]
# ## Main async runner
#
# This cell declares `main_async(batch_size)`, the high-level orchestrator that kicks off page scraping using batches to optimize processing. Tune `BATCH_SIZE`, `PAGES` and `MAX_CONCURRENCY` to balance throughput and rate-limit risk.

# %%
async def main_async(batch_size: int = 100):
    async with httpx.AsyncClient(headers=HEADERS, follow_redirects=True, timeout=30.0) as client:
        for start in range(1, PAGES + 1, batch_size):
            end = min(start + batch_size - 1, PAGES)
            page_range = list(range(start, end + 1))
            print(f"Processing pages {start} to {end} (batch size {batch_size})")
            tasks = [process_page(client, p) for p in page_range]
            page_dfs = await asyncio.gather(*tasks)
            # page_dfs are saved per page inside process_page (incremental),
            # so here we just log totals and free memory.
            total_rows = sum(len(df) for df in page_dfs if hasattr(df, 'shape'))
            print(f"Chunk {start}-{end}: fetched {len(page_dfs)} pages -> {total_rows} rows")
            # Explicitly drop references and run GC to free memory between batches
            del page_dfs
            import gc
            gc.collect()
            # Short pause between batches to reduce burstiness
            await asyncio.sleep(0.2)

    print("All batches processed")
    return

print("Async functions defined. Run the next cell to start scraping (it will process pages in batches).")
# Out:
# Async functions defined. Run the next cell to start scraping (it will process pages in batches).

# %%
# Execute async scraping (batched)
import pandas as pd, asyncio

BATCH_SIZE = 100  # adjust this value as needed (e.g., 50, 100)
try:
    asyncio.run(main_async(batch_size=BATCH_SIZE))
except RuntimeError:
    # Jupyter notebook compatibility
    import nest_asyncio, asyncio as _asyncio
    nest_asyncio.apply()
    _asyncio.get_event_loop().run_until_complete(main_async(batch_size=BATCH_SIZE))
# Out:
# Processing pages 1 to 100 (batch size 100)
# Page 15: 24 games detected
# Page 4: 24 games detected
# Page 2: 24 games detected
# Page 8: 24 games detected
# Page 13: 24 games detected
# Page 9: 24 games detected
# Page 3: 24 games detected
# Page 5: 24 games detected
# Page 17: 24 games detected
# Page 14: 24 games detected
# Page 10: 24 games detected
# Page 16: 24 games detected
# Page 1: 24 games detected
# Page 7: 24 games detected
# Page 6: 24 games detected
# Page 12: 24 games detected
# Page 11: 24 games detected
# Page 19: 24 games detected
# Page 20: 24 games detected
# Page 22: 24 games detected
# Page 21: 24 games detected
# Page 18: 24 games detected
# Page 24: 24 games detected
# Page 26: 24 games detected
# Page 30: 24 games detected
# Page 25: 24 games detected
# Page 27: 24 games detected
# Page 23: 24 games detected
# Page 29: 24 games detected
# Page 28: 24 games detected
# Page 32: 24 games detected
# Page 34: 24 games detected
# Page 31: 24 games detected
# Page 38: 24 games detected
# Page 33: 24 games detected
# Page 37: 24 games detected
# Page 39: 24 games detected
# Page 43: 24 games detected
# Page 35: 24 games detected
# Page 42: 24 games detected
# Page 41: 24 games detected
# Page 40: 24 games detected
# Page 47: 24 games detected
# Page 36: 24 games detected
# Page 51: 24 games detected
# Page 44: 24 games detected
# Page 48: 24 games detected
# Page 49: 24 games detected
# Page 45: 24 games detected
# Page 50: 24 games detected
# Page 55: 24 games detected
# Page 58: 24 games detected
# Page 53: 24 games detected
# Page 56: 24 games detected
# Page 46: 24 games detected
# Page 52: 24 games detected
# Page 61: 24 games detected
# Page 60: 24 games detected
# Page 57: 24 games detected
# Page 59: 24 games detected
# Page 54: 24 games detected
# Page 65: 24 games detected
# Page 68: 24 games detected
# Page 69: 24 games detected
# Page 63: 24 games detected
# Page 62: 24 games detected
# Page 70: 24 games detected
# Page 64: 24 games detected
# Page 75: 24 games detected
# Page 67: 24 games detected
# Page 72: 24 games detected
# Page 74: 24 games detected
# Page 77: 24 games detected
# Page 71: 24 games detected
# Page 73: 24 games detected
# Page 66: 24 games detected
# Page 76: 24 games detected
# Page 81: 24 games detected
# Page 79: 24 games detected
# Page 78: 24 games detected
# Page 84: 24 games detected
# Page 85: 24 games detected
# Page 87: 24 games detected
# Page 83: 24 games detected
# Page 82: 24 games detected
# Page 88: 24 games detected
# Page 80: 24 games detected
# Page 89: 24 games detected
# Page 90: 24 games detected
# Page 86: 24 games detected
# Page 95: 24 games detected
# Page 91: 24 games detected
# Page 92: 24 games detected
# Page 98: 24 games detected
# Page 96: 24 games detected
# Page 97: 24 games detected
# Page 99: 24 games detected
# Page 100: 24 games detected
# Page 94: 24 games detected
# Page 93: 24 games detected
# Saved page 15 -> 71 rows
# Saved page 4 -> 62 rows
# Saved page 2 -> 51 rows
# Saved page 8 -> 65 rows
# Saved page 13 -> 82 rows
# Saved page 9 -> 62 rows
# Saved page 3 -> 80 rows
# Saved page 5 -> 65 rows
# Saved page 17 -> 71 rows
# Saved page 14 -> 50 rows
# Saved page 10 -> 47 rows
# Saved page 16 -> 63 rows
# Saved page 1 -> 70 rows
# Saved page 7 -> 49 rows
# Saved page 6 -> 62 rows
# Saved page 12 -> 57 rows
# Saved page 11 -> 57 rows
# Saved page 19 -> 72 rows
# Saved page 20 -> 68 rows
# Saved page 22 -> 66 rows
# Saved page 21 -> 59 rows
# Saved page 24 -> 74 rows
# Saved page 18 -> 57 rows
# Saved page 26 -> 52 rows
# Saved page 30 -> 75 rows
# Saved page 25 -> 79 rows
# Saved page 27 -> 65 rows
# Saved page 23 -> 67 rows
# Saved page 29 -> 87 rows
# Saved page 28 -> 75 rows
# Saved page 32 -> 52 rows
# Saved page 34 -> 67 rows
# Saved page 31 -> 60 rows
# Saved page 38 -> 54 rows
# Saved page 33 -> 54 rows
# Saved page 37 -> 63 rows
# Saved page 39 -> 77 rows
# Saved page 43 -> 59 rows
# Saved page 35 -> 74 rows
# Saved page 42 -> 56 rows
# Saved page 41 -> 77 rows
# Saved page 40 -> 47 rows
# Saved page 47 -> 65 rows
# Saved page 36 -> 60 rows
# Saved page 51 -> 59 rows
# Saved page 44 -> 70 rows
# Saved page 48 -> 74 rows
# Saved page 49 -> 74 rows
# Saved page 45 -> 65 rows
# Saved page 50 -> 72 rows
# Saved page 55 -> 76 rows
# Saved page 58 -> 70 rows
# Saved page 53 -> 62 rows
# Saved page 56 -> 78 rows
# Saved page 46 -> 71 rows
# Saved page 52 -> 78 rows
# Saved page 61 -> 68 rows
# Saved page 60 -> 70 rows
# Saved page 57 -> 71 rows
# Saved page 59 -> 67 rows
# Saved page 54 -> 80 rows
# Saved page 65 -> 63 rows
# Saved page 68 -> 75 rows
# Saved page 69 -> 95 rows
# Saved page 63 -> 79 rows
# Saved page 62 -> 58 rows
# Saved page 70 -> 79 rows
# Saved page 64 -> 77 rows
# Saved page 75 -> 78 rows
# Saved page 67 -> 73 rows
# Saved page 72 -> 62 rows
# Saved page 74 -> 68 rows
# Saved page 77 -> 77 rows
# Saved page 71 -> 86 rows
# Saved page 73 -> 60 rows
# Saved page 66 -> 71 rows
# Saved page 76 -> 70 rows
# Saved page 81 -> 41 rows
# Saved page 79 -> 61 rows
# Saved page 78 -> 61 rows
# Saved page 84 -> 69 rows
# Saved page 85 -> 63 rows
# Saved page 87 -> 67 rows
# Saved page 83 -> 74 rows
# Saved page 82 -> 64 rows
# Saved page 88 -> 78 rows
# Saved page 80 -> 68 rows
# Saved page 89 -> 68 rows
# Saved page 90 -> 73 rows
# Saved page 86 -> 65 rows
# Saved page 95 -> 73 rows
# Saved page 91 -> 57 rows
# Saved page 92 -> 76 rows
# Saved page 98 -> 63 rows
# Saved page 96 -> 75 rows
# Saved page 97 -> 59 rows
# Saved page 99 -> 69 rows
# Saved page 100 -> 72 rows
# Saved page 94 -> 71 rows
# Saved page 93 -> 75 rows
# Chunk 1-100: fetched 100 pages -> 6743 rows
# Processing pages 101 to 200 (batch size 100)
# Page 115: 24 games detected
# Page 108: 24 games detected
# Page 106: 24 games detected
# Page 109: 24 games detected
# Page 112: 24 games detected
# Page 102: 24 games detected
# Page 107: 24 games detected
# Page 105: 24 games detected
# Page 113: 24 games detected
# Page 114: 24 games detected
# Page 110: 24 games detected
# Page 111: 24 games detected
# Page 103: 24 games detected
# Page 101: 24 games detected
# Page 104: 24 games detected
# Page 116: 24 games detected
# Page 120: 24 games detected
# Page 125: 24 games detected
# Page 118: 24 games detected
# Page 117: 24 games detected
# Page 124: 24 games detected
# Page 123: 24 games detected
# Page 119: 24 games detected
# Page 127: 24 games detected
# Page 126: 24 games detected
# Page 121: 24 games detected
# Page 131: 24 games detected
# Page 132: 24 games detected
# Page 134: 24 games detected
# Page 135: 24 games detected
# Page 139: 24 games detected
# Page 137: 24 games detected
# Page 122: 24 games detected
# Page 130: 24 games detected
# Page 138: 24 games detected
# Page 133: 24 games detected
# Page 136: 24 games detected
# Page 140: 24 games detected
# Page 129: 24 games detected
# Page 143: 24 games detected
# Page 141: 24 games detected
# Page 145: 24 games detected
# Page 128: 24 games detected
# Page 142: 24 games detected
# Page 147: 24 games detected
# Page 149: 24 games detected
# Page 148: 24 games detected
# Page 144: 24 games detected
# Page 146: 24 games detected
# Page 155: 24 games detected
# Page 157: 24 games detected
# Page 156: 24 games detected
# Page 151: 24 games detected
# Page 152: 24 games detected
# Page 164: 24 games detected
# Page 163: 24 games detected
# Page 158: 24 games detected
# Page 154: 24 games detected
# Page 153: 24 games detected
# Page 161: 24 games detected
# Page 165: 24 games detected
# Page 160: 24 games detected
# Page 162: 24 games detected
# Page 159: 24 games detected
# Page 168: 24 games detected
# Page 166: 24 games detected
# Page 170: 24 games detected
# Page 169: 24 games detected
# Page 173: 24 games detected
# Page 172: 24 games detected
# Page 181: 24 games detected
# Page 150: 24 games detected
# Page 175: 24 games detected
# Page 177: 24 games detected
# Page 179: 24 games detected
# Page 182: 24 games detected
# Page 174: 24 games detected
# Page 178: 24 games detected
# Page 180: 24 games detected
# Page 176: 24 games detected
# Page 171: 24 games detected
# Page 183: 24 games detected
# Page 167: 24 games detected
# Page 184: 24 games detected
# Page 187: 24 games detected
# Page 192: 24 games detected
# Page 188: 24 games detected
# Page 185: 24 games detected
# Page 186: 24 games detected
# Page 190: 24 games detected
# Page 197: 24 games detected
# Page 193: 24 games detected
# Page 196: 24 games detected
# Page 189: 24 games detected
# Page 200: 24 games detected
# Page 199: 24 games detected
# Page 191: 24 games detected
# Page 195: 24 games detected
# Page 198: 24 games detected
# Page 194: 24 games detected
# Saved page 115 -> 60 rows
# Saved page 108 -> 52 rows
# Saved page 106 -> 78 rows
# Saved page 109 -> 77 rows
# Saved page 112 -> 67 rows
# Saved page 102 -> 73 rows
# Saved page 107 -> 75 rows
# Saved page 105 -> 67 rows
# Saved page 113 -> 81 rows
# Saved page 114 -> 81 rows
# Saved page 110 -> 73 rows
# Saved page 111 -> 63 rows
# Saved page 103 -> 69 rows
# Saved page 101 -> 80 rows
# Saved page 104 -> 58 rows
# Saved page 116 -> 79 rows
# Saved page 125 -> 69 rows
# Saved page 120 -> 73 rows
# Saved page 118 -> 73 rows
# Saved page 117 -> 60 rows
# Saved page 124 -> 96 rows
# Saved page 123 -> 64 rows
# Saved page 119 -> 74 rows
# Saved page 127 -> 62 rows
# Saved page 126 -> 76 rows
# Saved page 121 -> 66 rows
# Saved page 131 -> 69 rows
# Saved page 132 -> 77 rows
# Saved page 134 -> 67 rows
# Saved page 135 -> 84 rows
# Saved page 139 -> 67 rows
# Saved page 137 -> 78 rows
# Saved page 122 -> 67 rows
# Saved page 138 -> 55 rows
# Saved page 130 -> 63 rows
# Saved page 133 -> 71 rows
# Saved page 136 -> 76 rows
# Saved page 140 -> 56 rows
# Saved page 129 -> 69 rows
# Saved page 143 -> 69 rows
# Saved page 141 -> 65 rows
# Saved page 145 -> 65 rows
# Saved page 128 -> 54 rows
# Saved page 142 -> 59 rows
# Saved page 147 -> 86 rows
# Saved page 149 -> 70 rows
# Saved page 148 -> 52 rows
# Saved page 144 -> 59 rows
# Saved page 146 -> 53 rows
# Saved page 155 -> 46 rows
# Saved page 157 -> 76 rows
# Saved page 156 -> 68 rows
# Saved page 151 -> 66 rows
# Saved page 152 -> 90 rows
# Saved page 164 -> 78 rows
# Saved page 163 -> 65 rows
# Saved page 158 -> 75 rows
# Saved page 154 -> 81 rows
# Saved page 153 -> 65 rows
# Saved page 161 -> 77 rows
# Saved page 165 -> 62 rows
# Saved page 160 -> 72 rows
# Saved page 162 -> 58 rows
# Saved page 159 -> 86 rows
# Saved page 168 -> 56 rows
# Saved page 166 -> 64 rows
# Saved page 170 -> 81 rows
# Saved page 169 -> 69 rows
# Saved page 173 -> 59 rows
# Saved page 172 -> 81 rows
# Saved page 181 -> 65 rows
# Saved page 150 -> 65 rows
# Saved page 175 -> 57 rows
# Saved page 177 -> 71 rows
# Saved page 179 -> 68 rows
# Saved page 182 -> 53 rows
# Saved page 174 -> 65 rows
# Saved page 178 -> 48 rows
# Saved page 180 -> 61 rows
# Saved page 176 -> 53 rows
# Saved page 171 -> 64 rows
# Saved page 183 -> 55 rows
# Saved page 167 -> 84 rows
# Saved page 184 -> 57 rows
# Saved page 187 -> 44 rows
# Saved page 192 -> 68 rows
# Saved page 188 -> 61 rows
# Saved page 185 -> 79 rows
# Saved page 186 -> 59 rows
# Saved page 190 -> 85 rows
# Saved page 197 -> 77 rows
# Saved page 193 -> 71 rows
# Saved page 196 -> 63 rows
# Saved page 189 -> 74 rows
# Saved page 200 -> 57 rows
# Saved page 199 -> 56 rows
# Saved page 191 -> 63 rows
# Saved page 195 -> 57 rows
# Saved page 198 -> 62 rows
# Saved page 194 -> 50 rows
# Chunk 101-200: fetched 100 pages -> 6744 rows
# Processing pages 201 to 300 (batch size 100)
# Page 203: 24 games detected
# Page 202: 24 games detected
# Page 206: 24 games detected
# Page 204: 24 games detected
# Page 215: 24 games detected
# Page 209: 24 games detected
# Page 201: 24 games detected
# Page 210: 24 games detected
# Page 205: 24 games detected
# Page 213: 24 games detected
# Page 208: 24 games detected
# Page 207: 24 games detected
# Page 211: 24 games detected
# Page 214: 24 games detected
# Page 219: 24 games detected
# Page 221: 24 games detected
# Page 217: 24 games detected
# Page 212: 24 games detected
# Page 216: 24 games detected
# Page 225: 24 games detected
# Page 223: 24 games detected
# Page 220: 24 games detected
# Page 228: 24 games detected
# Page 227: 24 games detected
# Page 231: 24 games detected
# Page 229: 24 games detected
# Page 226: 24 games detected
# Page 218: 24 games detected
# Page 235: 24 games detected
# Page 233: 24 games detected
# Page 232: 24 games detected
# Page 222: 24 games detected
# Page 224: 24 games detected
# Page 230: 24 games detected
# Page 239: 24 games detected
# Page 241: 24 games detected
# Page 236: 24 games detected
# Page 240: 24 games detected
# Page 243: 24 games detected
# Page 244: 24 games detected
# Page 247: 24 games detected
# Page 245: 24 games detected
# Page 234: 24 games detected
# Page 238: 24 games detected
# Page 248: 24 games detected
# Page 246: 24 games detected
# Page 251: 24 games detected
# Page 254: 24 games detected
# Page 256: 24 games detected
# Page 242: 24 games detected
# Page 250: 24 games detected
# Page 259: 24 games detected
# Page 257: 24 games detected
# Page 255: 24 games detected
# Page 252: 24 games detected
# Page 249: 24 games detected
# Page 237: 24 games detected
# Page 258: 24 games detected
# Page 261: 24 games detected
# Page 260: 24 games detected
# Page 264: 24 games detected
# Page 253: 24 games detected
# Page 268: 24 games detected
# Page 267: 24 games detected
# Page 265: 24 games detected
# Page 270: 24 games detected
# Page 262: 24 games detected
# Page 271: 24 games detected
# Page 272: 24 games detected
# Page 274: 24 games detected
# Page 269: 24 games detected
# Page 275: 24 games detected
# Page 266: 24 games detected
# Page 273: 24 games detected
# Page 277: 24 games detected
# Page 263: 24 games detected
# Page 278: 24 games detected
# Page 276: 24 games detected
# Page 279: 24 games detected
# Page 288: 24 games detected
# Page 283: 24 games detected
# Page 291: 24 games detected
# Page 286: 24 games detected
# Page 289: 24 games detected
# Page 280: 24 games detected
# Page 282: 24 games detected
# Page 284: 24 games detected
# Page 281: 24 games detected
# Page 295: 24 games detected
# Page 292: 24 games detected
# Page 298: 24 games detected
# Page 296: 24 games detected
# Page 294: 24 games detected
# Page 297: 24 games detected
# Page 285: 24 games detected
# Page 287: 24 games detected
# Page 300: 24 games detected
# Page 293: 24 games detected
# Page 290: 24 games detected
# Page 299: 24 games detected
# Saved page 203 -> 67 rows
# Saved page 202 -> 67 rows
# Saved page 206 -> 80 rows
# Saved page 204 -> 91 rows
# Saved page 215 -> 80 rows
# Saved page 209 -> 60 rows
# Saved page 201 -> 73 rows
# Saved page 210 -> 74 rows
# Saved page 205 -> 79 rows
# Saved page 213 -> 67 rows
# Saved page 208 -> 78 rows
# Saved page 207 -> 76 rows
# Saved page 211 -> 73 rows
# Saved page 214 -> 62 rows
# Saved page 219 -> 59 rows
# Saved page 221 -> 54 rows
# Saved page 217 -> 73 rows
# Saved page 212 -> 66 rows
# Saved page 216 -> 78 rows
# Saved page 225 -> 78 rows
# Saved page 223 -> 64 rows
# Saved page 220 -> 61 rows
# Saved page 228 -> 69 rows
# Saved page 227 -> 64 rows
# Saved page 231 -> 68 rows
# Saved page 229 -> 72 rows
# Saved page 226 -> 70 rows
# Saved page 218 -> 78 rows
# Saved page 235 -> 79 rows
# Saved page 233 -> 71 rows
# Saved page 232 -> 65 rows
# Saved page 222 -> 68 rows
# Saved page 224 -> 83 rows
# Saved page 230 -> 79 rows
# Saved page 239 -> 68 rows
# Saved page 241 -> 75 rows
# Saved page 236 -> 67 rows
# Saved page 240 -> 89 rows
# Saved page 243 -> 56 rows
# Saved page 244 -> 87 rows
# Saved page 247 -> 77 rows
# Saved page 245 -> 67 rows
# Saved page 234 -> 80 rows
# Saved page 238 -> 53 rows
# Saved page 248 -> 52 rows
# Saved page 246 -> 79 rows
# Saved page 251 -> 67 rows
# Saved page 254 -> 68 rows
# Saved page 256 -> 63 rows
# Saved page 250 -> 64 rows
# Saved page 259 -> 42 rows
# Saved page 242 -> 62 rows
# Saved page 257 -> 67 rows
# Saved page 255 -> 64 rows
# Saved page 252 -> 65 rows
# Saved page 249 -> 68 rows
# Saved page 237 -> 61 rows
# Saved page 258 -> 78 rows
# Saved page 261 -> 72 rows
# Saved page 260 -> 62 rows
# Saved page 264 -> 74 rows
# Saved page 253 -> 69 rows
# Saved page 268 -> 68 rows
# Saved page 267 -> 73 rows
# Saved page 265 -> 62 rows
# Saved page 270 -> 61 rows
# Saved page 262 -> 72 rows
# Saved page 271 -> 88 rows
# Saved page 272 -> 69 rows
# Saved page 274 -> 58 rows
# Saved page 269 -> 68 rows
# Saved page 275 -> 61 rows
# Saved page 266 -> 62 rows
# Saved page 273 -> 65 rows
# Saved page 277 -> 68 rows
# Saved page 263 -> 70 rows
# Saved page 278 -> 67 rows
# Saved page 276 -> 73 rows
# Saved page 279 -> 67 rows
# Saved page 288 -> 72 rows
# Saved page 283 -> 47 rows
# Saved page 291 -> 51 rows
# Saved page 286 -> 60 rows
# Saved page 289 -> 73 rows
# Saved page 280 -> 68 rows
# Saved page 282 -> 73 rows
# Saved page 284 -> 57 rows
# Saved page 281 -> 52 rows
# Saved page 295 -> 73 rows
# Saved page 292 -> 57 rows
# Saved page 298 -> 79 rows
# Saved page 296 -> 51 rows
# Saved page 294 -> 52 rows
# Saved page 297 -> 67 rows
# Saved page 285 -> 67 rows
# Saved page 287 -> 58 rows
# Saved page 300 -> 74 rows
# Saved page 293 -> 71 rows
# Saved page 290 -> 52 rows
# Saved page 299 -> 74 rows
# Chunk 201-300: fetched 100 pages -> 6802 rows
# Processing pages 301 to 400 (batch size 100)
# Page 311: 24 games detected
# Page 314: 24 games detected
# Page 315: 24 games detected
# Page 304: 24 games detected
# Page 310: 24 games detected
# Page 303: 24 games detected
# Page 308: 24 games detected
# Page 307: 24 games detected
# Page 312: 24 games detected
# Page 305: 24 games detected
# Page 309: 24 games detected
# Page 302: 24 games detected
# Page 301: 24 games detected
# Page 313: 24 games detected
# Page 306: 24 games detected
# Page 317: 24 games detected
# Page 316: 24 games detected
# Page 321: 24 games detected
# Page 319: 24 games detected
# Page 326: 24 games detected
# Page 323: 24 games detected
# Page 327: 24 games detected
# Page 322: 24 games detected
# Page 330: 24 games detected
# Page 324: 24 games detected
# Page 320: 24 games detected
# Page 328: 24 games detected
# Page 318: 24 games detected
# Page 329: 24 games detected
# Page 331: 24 games detected
# Page 333: 24 games detected
# Page 325: 24 games detected
# Page 337: 24 games detected
# Page 332: 24 games detected
# Page 334: 24 games detected
# Page 336: 24 games detected
# Page 345: 24 games detected
# Page 335: 24 games detected
# Page 338: 24 games detected
# Page 340: 24 games detected
# Page 344: 24 games detected
# Page 341: 24 games detected
# Page 346: 24 games detected
# Page 339: 24 games detected
# Page 350: 24 games detected
# Page 348: 24 games detected
# Page 354: 24 games detected
# Page 349: 24 games detected
# Page 352: 24 games detected
# Page 353: 24 games detected
# Page 342: 24 games detected
# Page 347: 24 games detected
# Page 359: 24 games detected
# Page 351: 24 games detected
# Page 356: 24 games detected
# Page 355: 24 games detected
# Page 358: 24 games detected
# Page 357: 24 games detected
# Page 362: 24 games detected
# Page 360: 24 games detected
# Page 363: 24 games detected
# Page 365: 24 games detected
# Page 361: 24 games detected
# Page 364: 24 games detected
# Page 367: 24 games detected
# Page 368: 24 games detected
# Page 372: 24 games detected
# Page 378: 24 games detected
# Page 370: 24 games detected
# Page 377: 24 games detected
# Page 381: 24 games detected
# Page 374: 24 games detected
# Page 343: 24 games detected
# Page 376: 24 games detected
# Page 380: 24 games detected
# Page 382: 24 games detected
# Page 373: 24 games detected
# Page 369: 24 games detected
# Page 379: 24 games detected
# Page 375: 24 games detected
# Page 384: 24 games detected
# Page 371: 24 games detected
# Page 366: 24 games detected
# Page 385: 24 games detected
# Page 383: 24 games detected
# Page 386: 24 games detected
# Page 388: 24 games detected
# Page 393: 24 games detected
# Page 398: 24 games detected
# Page 389: 24 games detected
# Page 391: 24 games detected
# Page 400: 24 games detected
# Page 390: 24 games detected
# Page 394: 24 games detected
# Page 397: 24 games detected
# Page 392: 24 games detected
# Page 399: 24 games detected
# Page 395: 24 games detected
# Page 387: 24 games detected
# Page 396: 24 games detected
# Saved page 311 -> 73 rows
# Saved page 314 -> 67 rows
# Saved page 315 -> 70 rows
# Saved page 304 -> 73 rows
# Saved page 310 -> 57 rows
# Saved page 303 -> 73 rows
# Saved page 308 -> 63 rows
# Saved page 307 -> 47 rows
# Saved page 312 -> 63 rows
# Saved page 305 -> 65 rows
# Saved page 309 -> 74 rows
# Saved page 302 -> 78 rows
# Saved page 301 -> 62 rows
# Saved page 313 -> 75 rows
# Saved page 306 -> 71 rows
# Saved page 317 -> 68 rows
# Saved page 316 -> 63 rows
# Saved page 321 -> 60 rows
# Saved page 319 -> 84 rows
# Saved page 326 -> 60 rows
# Saved page 323 -> 52 rows
# Saved page 327 -> 58 rows
# Saved page 322 -> 63 rows
# Saved page 330 -> 57 rows
# Saved page 324 -> 67 rows
# Saved page 320 -> 63 rows
# Saved page 328 -> 55 rows
# Saved page 318 -> 61 rows
# Saved page 329 -> 72 rows
# Saved page 331 -> 50 rows
# Saved page 333 -> 65 rows
# Saved page 325 -> 63 rows
# Saved page 337 -> 80 rows
# Saved page 332 -> 69 rows
# Saved page 334 -> 79 rows
# Saved page 336 -> 73 rows
# Saved page 345 -> 50 rows
# Saved page 335 -> 83 rows
# Saved page 338 -> 62 rows
# Saved page 340 -> 63 rows
# Saved page 344 -> 63 rows
# Saved page 341 -> 59 rows
# Saved page 346 -> 63 rows
# Saved page 339 -> 60 rows
# Saved page 350 -> 54 rows
# Saved page 348 -> 48 rows
# Saved page 354 -> 64 rows
# Saved page 352 -> 57 rows
# Saved page 349 -> 62 rows
# Saved page 353 -> 66 rows
# Saved page 342 -> 78 rows
# Saved page 347 -> 54 rows
# Saved page 359 -> 62 rows
# Saved page 351 -> 79 rows
# Saved page 356 -> 59 rows
# Saved page 355 -> 54 rows
# Saved page 358 -> 61 rows
# Saved page 357 -> 57 rows
# Saved page 362 -> 69 rows
# Saved page 360 -> 69 rows
# Saved page 363 -> 57 rows
# Saved page 365 -> 62 rows
# Saved page 361 -> 64 rows
# Saved page 364 -> 61 rows
# Saved page 367 -> 70 rows
# Saved page 368 -> 61 rows
# Saved page 372 -> 69 rows
# Saved page 378 -> 63 rows
# Saved page 370 -> 54 rows
# Saved page 377 -> 63 rows
# Saved page 381 -> 81 rows
# Saved page 374 -> 51 rows
# Saved page 343 -> 68 rows
# Saved page 376 -> 70 rows
# Saved page 380 -> 62 rows
# Saved page 382 -> 66 rows
# Saved page 373 -> 65 rows
# Saved page 369 -> 69 rows
# Saved page 379 -> 55 rows
# Saved page 375 -> 66 rows
# Saved page 384 -> 55 rows
# Saved page 371 -> 77 rows
# Saved page 366 -> 61 rows
# Saved page 385 -> 65 rows
# Saved page 383 -> 77 rows
# Saved page 386 -> 66 rows
# Saved page 388 -> 69 rows
# Saved page 393 -> 60 rows
# Saved page 398 -> 57 rows
# Saved page 389 -> 59 rows
# Saved page 391 -> 72 rows
# Saved page 400 -> 62 rows
# Saved page 390 -> 54 rows
# Saved page 394 -> 72 rows
# Saved page 397 -> 57 rows
# Saved page 392 -> 62 rows
# Saved page 399 -> 61 rows
# Saved page 395 -> 58 rows
# Saved page 387 -> 56 rows
# Saved page 396 -> 62 rows
# Chunk 301-400: fetched 100 pages -> 6408 rows
# Processing pages 401 to 500 (batch size 100)
# Page 405: 24 games detected
# Page 404: 24 games detected
# Page 412: 24 games detected
# Page 407: 24 games detected
# Page 415: 24 games detected
# Page 413: 24 games detected
# Page 410: 24 games detected
# Page 406: 24 games detected
# Page 408: 24 games detected
# Page 414: 24 games detected
# Page 402: 24 games detected
# Page 401: 24 games detected
# Page 411: 24 games detected
# Page 403: 24 games detected
# Page 409: 24 games detected
# Page 419: 24 games detected
# Page 421: 24 games detected
# Page 418: 24 games detected
# Page 416: 24 games detected
# Page 423: 24 games detected
# Page 417: 24 games detected
# Page 427: 24 games detected
# Page 429: 24 games detected
# Page 426: 24 games detected
# Page 428: 24 games detected
# Page 420: 24 games detected
# Page 434: 24 games detected
# Page 430: 24 games detected
# Page 431: 24 games detected
# Page 425: 24 games detected
# Page 435: 24 games detected
# Page 422: 24 games detected
# Page 432: 24 games detected
# Page 424: 24 games detected
# Page 436: 24 games detected
# Page 438: 24 games detected
# Page 440: 24 games detected
# Page 442: 24 games detected
# Page 444: 24 games detected
# Page 437: 24 games detected
# Page 439: 24 games detected
# Page 441: 24 games detected
# Page 433: 24 games detected
# Page 446: 24 games detected
# Page 445: 24 games detected
# Page 448: 24 games detected
# Page 443: 24 games detected
# Page 449: 24 games detected
# Page 453: 24 games detected
# Page 447: 24 games detected
# Page 450: 24 games detected
# Page 452: 24 games detected
# Page 455: 24 games detected
# Page 459: 24 games detected
# Page 454: 24 games detected
# Page 456: 24 games detected
# Page 458: 24 games detected
# Page 460: 24 games detected
# Page 462: 24 games detected
# Page 463: 24 games detected
# Page 461: 24 games detected
# Page 469: 24 games detected
# Page 451: 24 games detected
# Page 470: 24 games detected
# Page 464: 24 games detected
# Page 466: 24 games detected
# Page 465: 24 games detected
# Page 467: 24 games detected
# Page 471: 24 games detected
# Page 475: 24 games detected
# Page 468: 24 games detected
# Page 457: 24 games detected
# Page 472: 24 games detected
# Page 476: 24 games detected
# Page 474: 24 games detected
# Page 479: 24 games detected
# Page 477: 24 games detected
# Page 478: 24 games detected
# Page 473: 24 games detected
# Page 480: 24 games detected
# Page 488: 24 games detected
# Page 481: 24 games detected
# Page 484: 24 games detected
# Page 485: 24 games detected
# Page 487: 24 games detected
# Page 483: 24 games detected
# Page 489: 24 games detected
# Page 482: 24 games detected
# Page 491: 24 games detected
# Page 497: 24 games detected
# Page 486: 24 games detected
# Page 490: 24 games detected
# Page 494: 24 games detected
# Page 495: 24 games detected
# Page 492: 24 games detected
# Page 493: 24 games detected
# Page 499: 24 games detected
# Page 496: 24 games detected
# Page 500: 24 games detected
# Page 498: 24 games detected
# Saved page 405 -> 50 rows
# Saved page 404 -> 57 rows
# Saved page 412 -> 70 rows
# Saved page 407 -> 56 rows
# Saved page 415 -> 75 rows
# Saved page 413 -> 66 rows
# Saved page 410 -> 53 rows
# Saved page 406 -> 65 rows
# Saved page 408 -> 62 rows
# Saved page 414 -> 65 rows
# Saved page 402 -> 61 rows
# Saved page 401 -> 60 rows
# Saved page 411 -> 47 rows
# Saved page 409 -> 49 rows
# Saved page 403 -> 53 rows
# Saved page 419 -> 40 rows
# Saved page 421 -> 50 rows
# Saved page 418 -> 71 rows
# Saved page 416 -> 58 rows
# Saved page 423 -> 51 rows
# Saved page 417 -> 64 rows
# Saved page 427 -> 59 rows
# Saved page 429 -> 77 rows
# Saved page 426 -> 63 rows
# Saved page 428 -> 63 rows
# Saved page 420 -> 62 rows
# Saved page 434 -> 65 rows
# Saved page 430 -> 73 rows
# Saved page 431 -> 71 rows
# Saved page 425 -> 61 rows
# Saved page 435 -> 64 rows
# Saved page 422 -> 60 rows
# Saved page 432 -> 53 rows
# Saved page 424 -> 56 rows
# Saved page 436 -> 53 rows
# Saved page 438 -> 67 rows
# Saved page 440 -> 63 rows
# Saved page 442 -> 66 rows
# Saved page 444 -> 65 rows
# Saved page 437 -> 82 rows
# Saved page 439 -> 59 rows
# Saved page 433 -> 63 rows
# Saved page 441 -> 67 rows
# Saved page 446 -> 61 rows
# Saved page 445 -> 55 rows
# Saved page 448 -> 55 rows
# Saved page 449 -> 54 rows
# Saved page 443 -> 49 rows
# Saved page 453 -> 66 rows
# Saved page 447 -> 59 rows
# Saved page 450 -> 65 rows
# Saved page 452 -> 49 rows
# Saved page 455 -> 72 rows
# Saved page 459 -> 47 rows
# Saved page 454 -> 51 rows
# Saved page 456 -> 51 rows
# Saved page 458 -> 58 rows
# Saved page 460 -> 61 rows
# Saved page 462 -> 63 rows
# Saved page 463 -> 55 rows
# Saved page 461 -> 73 rows
# Saved page 469 -> 55 rows
# Saved page 451 -> 48 rows
# Saved page 470 -> 54 rows
# Saved page 464 -> 61 rows
# Saved page 466 -> 57 rows
# Saved page 465 -> 56 rows
# Saved page 471 -> 49 rows
# Saved page 467 -> 56 rows
# Saved page 475 -> 66 rows
# Saved page 468 -> 66 rows
# Saved page 472 -> 69 rows
# Saved page 457 -> 55 rows
# Saved page 479 -> 55 rows
# Saved page 476 -> 61 rows
# Saved page 474 -> 61 rows
# Saved page 477 -> 59 rows
# Saved page 478 -> 55 rows
# Saved page 473 -> 50 rows
# Saved page 480 -> 74 rows
# Saved page 488 -> 51 rows
# Saved page 481 -> 58 rows
# Saved page 484 -> 65 rows
# Saved page 485 -> 65 rows
# Saved page 487 -> 66 rows
# Saved page 489 -> 56 rows
# Saved page 482 -> 60 rows
# Saved page 491 -> 51 rows
# Saved page 483 -> 55 rows
# Saved page 497 -> 61 rows
# Saved page 486 -> 70 rows
# Saved page 490 -> 45 rows
# Saved page 494 -> 81 rows
# Saved page 495 -> 54 rows
# Saved page 493 -> 48 rows
# Saved page 492 -> 58 rows
# Saved page 499 -> 47 rows
# Saved page 496 -> 58 rows
# Saved page 500 -> 46 rows
# Saved page 498 -> 52 rows
# Chunk 401-500: fetched 100 pages -> 5933 rows
# Processing pages 501 to 580 (batch size 100)
# Page 507: 24 games detected
# Page 514: 24 games detected
# Page 508: 24 games detected
# Page 510: 24 games detected
# Page 506: 24 games detected
# Page 512: 24 games detected
# Page 502: 24 games detected
# Page 505: 24 games detected
# Page 515: 24 games detected
# Page 511: 24 games detected
# Page 504: 24 games detected
# Page 509: 24 games detected
# Page 501: 24 games detected
# Page 516: 24 games detected
# Page 513: 24 games detected
# Page 517: 24 games detected
# Page 503: 24 games detected
# Page 518: 24 games detected
# Page 521: 24 games detected
# Page 519: 24 games detected
# Page 528: 24 games detected
# Page 525: 24 games detected
# Page 524: 24 games detected
# Page 523: 24 games detected
# Page 529: 24 games detected
# Page 526: 24 games detected
# Page 520: 24 games detected
# Page 522: 24 games detected
# Page 527: 24 games detected
# Page 532: 24 games detected
# Page 531: 24 games detected
# Page 534: 24 games detected
# Page 536: 24 games detected
# Page 530: 24 games detected
# Page 541: 24 games detected
# Page 540: 24 games detected
# Page 533: 24 games detected
# Page 539: 24 games detected
# Page 542: 24 games detected
# Page 535: 24 games detected
# Page 538: 24 games detected
# Page 543: 24 games detected
# Page 537: 24 games detected
# Page 551: 24 games detected
# Page 549: 24 games detected
# Page 546: 24 games detected
# Page 545: 24 games detected
# Page 547: 24 games detected
# Page 544: 24 games detected
# Page 552: 24 games detected
# Page 548: 24 games detected
# Page 555: 24 games detected
# Page 553: 24 games detected
# Page 550: 24 games detected
# Page 557: 24 games detected
# Page 559: 24 games detected
# Page 554: 24 games detected
# Page 556: 24 games detected
# Page 566: 24 games detected
# Page 567: 24 games detected
# Page 560: 24 games detected
# Page 561: 24 games detected
# Page 558: 24 games detected
# Page 569: 24 games detected
# Page 563: 24 games detected
# Page 568: 24 games detected
# Page 571: 24 games detected
# Page 562: 24 games detected
# Page 577: 24 games detected
# Page 565: 24 games detected
# Page 572: 24 games detected
# Page 564: 24 games detected
# Page 579: 24 games detected
# Page 578: 24 games detected
# Page 575: 24 games detected
# Page 570: 24 games detected
# Page 576: 24 games detected
# Page 573: 24 games detected
# Page 574: 24 games detected
# Page 580: 18 games detected
# Saved page 507 -> 44 rows
# Saved page 514 -> 54 rows
# Saved page 508 -> 45 rows
# Saved page 510 -> 64 rows
# Saved page 506 -> 42 rows
# Saved page 512 -> 51 rows
# Saved page 502 -> 56 rows
# Saved page 505 -> 54 rows
# Saved page 515 -> 41 rows
# Saved page 511 -> 58 rows
# Saved page 504 -> 46 rows
# Saved page 509 -> 58 rows
# Saved page 501 -> 58 rows
# Saved page 516 -> 54 rows
# Saved page 513 -> 56 rows
# Saved page 517 -> 54 rows
# Saved page 503 -> 56 rows
# Saved page 518 -> 51 rows
# Saved page 521 -> 52 rows
# Saved page 519 -> 52 rows
# Saved page 528 -> 53 rows
# Saved page 525 -> 54 rows
# Saved page 524 -> 52 rows
# Saved page 523 -> 67 rows
# Saved page 529 -> 63 rows
# Saved page 526 -> 47 rows
# Saved page 520 -> 53 rows
# Saved page 522 -> 66 rows
# Saved page 527 -> 56 rows
# Saved page 532 -> 49 rows
# Saved page 531 -> 59 rows
# Saved page 534 -> 63 rows
# Saved page 536 -> 54 rows
# Saved page 530 -> 46 rows
# Saved page 541 -> 57 rows
# Saved page 540 -> 55 rows
# Saved page 533 -> 57 rows
# Saved page 539 -> 41 rows
# Saved page 542 -> 58 rows
# Saved page 535 -> 53 rows
# Saved page 538 -> 50 rows
# Saved page 543 -> 52 rows
# Saved page 537 -> 61 rows
# Saved page 551 -> 57 rows
# Saved page 549 -> 57 rows
# Saved page 546 -> 46 rows
# Saved page 545 -> 50 rows
# Saved page 547 -> 48 rows
# Saved page 544 -> 45 rows
# Saved page 552 -> 49 rows
# Saved page 548 -> 52 rows
# Saved page 555 -> 53 rows
# Saved page 553 -> 49 rows
# Saved page 550 -> 42 rows
# Saved page 557 -> 53 rows
# Saved page 559 -> 59 rows
# Saved page 554 -> 40 rows
# Saved page 556 -> 46 rows
# Saved page 566 -> 42 rows
# Saved page 567 -> 56 rows
# Saved page 560 -> 54 rows
# Saved page 561 -> 47 rows
# Saved page 558 -> 57 rows
# Saved page 569 -> 49 rows
# Saved page 563 -> 73 rows
# Saved page 568 -> 59 rows
# Saved page 571 -> 54 rows
# Saved page 562 -> 60 rows
# Saved page 577 -> 50 rows
# Saved page 565 -> 65 rows
# Saved page 572 -> 46 rows
# Saved page 564 -> 50 rows
# Saved page 578 -> 42 rows
# Saved page 579 -> 39 rows
# Saved page 575 -> 60 rows
# Saved page 570 -> 50 rows
# Saved page 576 -> 40 rows
# Saved page 580 -> 34 rows
# Saved page 573 -> 55 rows
# Saved page 574 -> 59 rows
# Chunk 501-580: fetched 80 pages -> 4199 rows
# All batches processed
# C:\Users\Stadyn\AppData\Local\Temp\ipykernel_42124\2942427001.py:11: RuntimeWarning: coroutine 'main_async' was never awaited
#   _asyncio.get_event_loop().run_until_complete(main_async(batch_size=BATCH_SIZE))
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# ### Concatenate all pages csvs

# %%
import pandas as pd
# Create a list of pages dataframes
pages = [pd.read_csv(f'pages/games_data-page{p}.csv') for p in range(1, PAGES + 1)]
# Concatenate all dataframes into one
df_ultimate = pd.concat(pages, ignore_index=True).reset_index(drop=True)

# %%
# Fix names of games with numbers at the start
df_ultimate['name'] = df_ultimate['name'].str.strip().replace(r'^\d{1,3}(,\d{3})+\.\s*', '', regex=True)

# %% [markdown]
# # The Dataset
#
# The columns are:
# * **name**: Name of the game
# * **platform**: Platform on which the game was released
# * **release_date**: The date the game was released (first release date on any platform; does not include separate dates for re-releases on other consoles)
# * **metascore**: Metascore, the average rating given by Metacritic based on reviews from professional critics
# * **user score**: Average rating given by Metacritic users
# * **developer**: Game developer
# * **publisher**: Game publisher(s)
# * **genre**: Game genre(s), may include mixed genres

# %%
df_ultimate.head(15)
# Out:
#                                        name           platform release_date  \
# 0      The Legend of Zelda: Ocarina of Time        Nintendo 64   1998-11-23
# 1                               SoulCalibur          Dreamcast   1999-09-08
# 2                               SoulCalibur  iOS (iPhone/iPad)   1999-09-08
# 3                               SoulCalibur           Xbox 360   1999-09-08
# 4                       Grand Theft Auto IV      PlayStation 3   2008-04-29
# 5                       Grand Theft Auto IV           Xbox 360   2008-04-29
# 6                       Grand Theft Auto IV                 PC   2008-04-29
# 7                        Super Mario Galaxy                Wii   2007-11-12
# 8                        Super Mario Galaxy    Nintendo Switch   2007-11-12
# 9                      Super Mario Galaxy 2                Wii   2010-05-23
# 10                     Super Mario Galaxy 2    Nintendo Switch   2010-05-23
# 11  The Legend of Zelda: Breath of the Wild              Wii U   2017-03-03
# 12  The Legend of Zelda: Breath of the Wild    Nintendo Switch   2017-03-03
# 13                 Tony Hawk's Pro Skater 3               Xbox   2001-10-30
# 14                 Tony Hawk's Pro Skater 3      PlayStation 2   2001-10-30
#
#    metascore user_score                developer  \
# 0         99        9.1                 Nintendo
# 1         98        7.6                    Namco
# 2         73        7.8                    Namco
# 3         79        7.3                    Namco
# 4         98        8.0           Rockstar North
# 5         98        8.3           Rockstar North
# 6         90        7.8           Rockstar North
# 7         97        9.1                 Nintendo
# 8        tbd        NaN                 Nintendo
# 9         97        9.0       Nintendo EAD Tokyo
# 10       tbd        NaN       Nintendo EAD Tokyo
# 11        96        8.5                 Nintendo
# 12        97        8.9                 Nintendo
# 13        93        6.7  Neversoft Entertainment
# 14        97        7.6  Neversoft Entertainment
#
#                        publisher                  genre
# 0      ['Nintendo', 'Gradiente']  ['Open-World Action']
# 1                      ['Namco']        ['3D Fighting']
# 2                      ['Namco']        ['3D Fighting']
# 3                      ['Namco']        ['3D Fighting']
# 4   ['Rockstar Games', 'Capcom']  ['Open-World Action']
# 5   ['Rockstar Games', 'Capcom']  ['Open-World Action']
# 6   ['Rockstar Games', 'Capcom']  ['Open-World Action']
# 7                   ['Nintendo']      ['3D Platformer']
# 8                   ['Nintendo']      ['3D Platformer']
# 9           ['Nintendo', 'iQue']      ['3D Platformer']
# 10          ['Nintendo', 'iQue']      ['3D Platformer']
# 11                  ['Nintendo']  ['Open-World Action']
# 12                  ['Nintendo']  ['Open-World Action']
# 13     ['Activision', 'Success']            ['Skating']
# 14     ['Activision', 'Success']            ['Skating']

# %%
df_ultimate.tail(15)
# Out:
#                                                name          platform  \
# 36814                               Deal or No Deal                PC
# 36815                               Deal or No Deal                DS
# 36816                               Deal or No Deal  Game Boy Advance
# 36817                               Deal or No Deal               Wii
# 36818               Alone in the Dark: Illumination                PC
# 36819                     Ride to Hell: Retribution                PC
# 36820                     Ride to Hell: Retribution     PlayStation 3
# 36821                     Ride to Hell: Retribution          Xbox 360
# 36822                                  SPOGS Racing               Wii
# 36823                                  SPOGS Racing                PC
# 36824       Double Dragon II: Wander of the Dragons          Xbox 360
# 36825                        Vroom in the Night Sky   Nintendo Switch
# 36826                                         Yaris          Xbox 360
# 36827  Family Party: 30 Great Games Obstacle Arcade             Wii U
# 36828                                     Stormgate                PC
#
#       release_date metascore user_score               developer  \
# 36814   2007-07-23       tbd        NaN        Artefacts Studio
# 36815   2007-07-23        20        3.8        Artefacts Studio
# 36816   2007-07-23        56        5.0        Artefacts Studio
# 36817   2007-07-23       NaN        NaN        Artefacts Studio
# 36818   2015-06-11        19        1.3                Pure FPS
# 36819   2013-06-25        16        1.4               Eutechnyx
# 36820   2013-06-25        13        1.1               Eutechnyx
# 36821   2013-06-25        19        1.3               Eutechnyx
# 36822   2008-07-07        18        6.3            Pronto Games
# 36823   2008-07-07       NaN        NaN            Pronto Games
# 36824   2013-04-05        17        1.6                 Gravity
# 36825   2017-04-05        17        3.3                 Poisoft
# 36826   2007-10-10        17        5.2  Backbone Entertainment
# 36827   2012-12-04        11        2.8           Art Co., Ltd.
# 36828   2025-08-05       tbd        4.3     Frost Giant Studios
#
#                                                publisher                 genre
# 36814  ['Destination Software', 'Mindscape', 'Koch Me...            ['Trivia']
# 36815  ['Destination Software', 'Mindscape', 'Koch Me...            ['Trivia']
# 36816  ['Destination Software', 'Mindscape', 'Koch Me...            ['Trivia']
# 36817  ['Destination Software', 'Mindscape', 'Koch Me...            ['Trivia']
# 36818                                       ['Atari SA']          ['Survival']
# 36819                                    ['Deep Silver']  ['Action Adventure']
# 36820                                    ['Deep Silver']  ['Action Adventure']
# 36821                                    ['Deep Silver']  ['Action Adventure']
# 36822                                      ['D2C Games']       ['Auto Racing']
# 36823                                      ['D2C Games']       ['Auto Racing']
# 36824                                            ['CFK']    ["2D Beat-'Em-Up"]
# 36825                                        ['Poisoft']            ['Biking']
# 36826                         ['Backbone Entertainment']       ['Auto Racing']
# 36827              ['D3Publisher', 'Namco Bandai Games']             ['Party']
# 36828                            ['Frost Giant Studios']       ['Command RTS']

# %%
# Explore the dataframe
df_ultimate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36829 entries, 0 to 36828
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          36829 non-null  object
#  1   platform      36829 non-null  object
#  2   release_date  36786 non-null  object
#  3   metascore     31105 non-null  object
#  4   user_score    24495 non-null  object
#  5   developer     36818 non-null  object
#  6   publisher     36829 non-null  object
#  7   genre         36829 non-null  object
# dtypes: object(8)
# memory usage: 2.2+ MB

# %%
# Save the raw dataframe to CSV
df_ultimate.to_csv('metacritic_dataset_raw.csv', index=False)

# %% [markdown]
# ## Data Cleaning

# %%
# Load raw dataset
df_clean = pd.read_csv('metacritic_dataset_raw.csv')

# %%
# Examine cases with null columns
df_clean[df_clean.isnull().any(axis=1)].head(15)
# Out:
#                              name          platform release_date metascore  \
# 8              Super Mario Galaxy   Nintendo Switch   2007-11-12       tbd
# 10           Super Mario Galaxy 2   Nintendo Switch   2010-05-23       tbd
# 19       Tony Hawk's Pro Skater 3       Nintendo 64   2001-10-30       NaN
# 33                  Metroid Prime               Wii   2002-11-17       NaN
# 37           Grand Theft Auto III              Xbox   2001-10-22       NaN
# 38           Grand Theft Auto III     PlayStation 4   2001-10-22       NaN
# 39           Grand Theft Auto III  Game Boy Advance   2001-10-22       NaN
# 52                  GoldenEye 007          Xbox One   1997-08-25       NaN
# 53                  GoldenEye 007     Xbox Series X   1997-08-25       NaN
# 66                       Tekken 3         Dreamcast   1998-04-29       NaN
# 76                     Elden Ring     PlayStation 5   2022-02-25       NaN
# 82                      Half-Life     PlayStation 2   1998-11-19       NaN
# 88   Grand Theft Auto Double Pack     PlayStation 2   2003-11-04       NaN
# 96  Grand Theft Auto: San Andreas     PlayStation 3   2004-10-26       NaN
# 97  Grand Theft Auto: San Andreas     PlayStation 4   2004-10-26       NaN
#
#    user_score                developer  \
# 8         NaN                 Nintendo
# 10        NaN       Nintendo EAD Tokyo
# 19        NaN  Neversoft Entertainment
# 33        NaN            Retro Studios
# 37        NaN               DMA Design
# 38        NaN               DMA Design
# 39        NaN               DMA Design
# 52        NaN                Rare Ltd.
# 53        NaN                Rare Ltd.
# 66        NaN                    Namco
# 76        NaN            From Software
# 82        NaN           Valve Software
# 88        NaN          Rockstar Vienna
# 96        NaN           Rockstar North
# 97        NaN           Rockstar North
#
#                                             publisher                  genre
# 8                                        ['Nintendo']      ['3D Platformer']
# 10                               ['Nintendo', 'iQue']      ['3D Platformer']
# 19                          ['Activision', 'Success']            ['Skating']
# 33                                       ['Nintendo']                ['FPS']
# 37  ['Rockstar Games', 'SCEA', 'Capcom', 'Take-Two...  ['Open-World Action']
# 38  ['Rockstar Games', 'SCEA', 'Capcom', 'Take-Two...  ['Open-World Action']
# 39  ['Rockstar Games', 'SCEA', 'Capcom', 'Take-Two...  ['Open-World Action']
# 52                          ['Nintendo', 'Gradiente']                ['FPS']
# 53                          ['Nintendo', 'Gradiente']                ['FPS']
# 66                                  ['Namco', 'SCEE']        ['3D Fighting']
# 76            ['Bandai Namco Games', 'From Software']         ['Action RPG']
# 82  ['Sierra Entertainment', 'Valve Software', 'So...                ['FPS']
# 88                       ['Rockstar Games', 'Capcom']        ['Compilation']
# 96  ['Rockstar Games', 'SCEA', 'Capcom', 'Take-Two...  ['Open-World Action']
# 97  ['Rockstar Games', 'SCEA', 'Capcom', 'Take-Two...  ['Open-World Action']

# %%
# Examine cases with Metascore 'tbd', which is the same as no score
df_clean[df_clean['metascore'] == 'tbd']
# Out:
#                                                     name           platform  \
# 8                                     Super Mario Galaxy    Nintendo Switch
# 10                                  Super Mario Galaxy 2    Nintendo Switch
# 36                                  Grand Theft Auto III  iOS (iPhone/iPad)
# 51                                         GoldenEye 007           Xbox 360
# 70     The House in Fata Morgana - Dreams of the Reve...      PlayStation 4
# ...                                                  ...                ...
# 36806                           Fast & Furious: Showdown                3DS
# 36808                            Drake of the 99 Dragons                 PC
# 36811         Afro Samurai 2: Revenge of Kuma Volume One           Xbox One
# 36814                                    Deal or No Deal                 PC
# 36828                                          Stormgate                 PC
#
#       release_date metascore user_score            developer  \
# 8       2007-11-12       tbd        NaN             Nintendo
# 10      2010-05-23       tbd        NaN   Nintendo EAD Tokyo
# 36      2001-10-22       tbd        7.3           DMA Design
# 51      1997-08-25       tbd        6.4            Rare Ltd.
# 70      2021-04-09       tbd        7.8                HuneX
# ...            ...       ...        ...                  ...
# 36806   2013-05-21       tbd        2.0      Firebrand Games
# 36808   2003-11-03       tbd        2.0              Idol FX
# 36811   2015-09-22       tbd        2.6          Versus Evil
# 36814   2007-07-23       tbd        NaN     Artefacts Studio
# 36828   2025-08-05       tbd        4.3  Frost Giant Studios
#
#                                                publisher  \
# 8                                           ['Nintendo']
# 10                                  ['Nintendo', 'iQue']
# 36     ['Rockstar Games', 'SCEA', 'Capcom', 'Take-Two...
# 51                             ['Nintendo', 'Gradiente']
# 70     ['Limited Run Games', 'dramatic create', 'HuneX']
# ...                                                  ...
# 36806                                     ['Activision']
# 36808                                        ['Majesco']
# 36811                                    ['Versus Evil']
# 36814  ['Destination Software', 'Mindscape', 'Koch Me...
# 36828                            ['Frost Giant Studios']
#
#                           genre
# 8             ['3D Platformer']
# 10            ['3D Platformer']
# 36        ['Open-World Action']
# 51                      ['FPS']
# 70             ['Visual Novel']
# ...                         ...
# 36806           ['Auto Racing']
# 36808  ['Third Person Shooter']
# 36811        ["3D Beat-'Em-Up"]
# 36814                ['Trivia']
# 36828           ['Command RTS']
#
# [4987 rows x 8 columns]

# %%
# Examine cases with user_score 'tbd', which is the same as no score
df_clean[df_clean['user_score'] == 'tbd']
# Out:
#                                                     name           platform  \
# 16480                                           Coridden                 PC
# 16995                                         Pinball FX      PlayStation 4
# 20765  Marvel's Guardians of the Galaxy - Episode 2: ...  iOS (iPhone/iPad)
# 36351                                       Pimp My Ride                Wii
#
#       release_date metascore user_score       developer           publisher  \
# 16480   2025-01-29        75        tbd       Aftnareld  ['Anshar Studios']
# 16995   2023-02-16       tbd        tbd     Zen Studios     ['Zen Studios']
# 20765   2017-06-06       tbd        tbd  Telltale Games  ['Telltale Games']
# 36351   2006-12-06        26        tbd       Eutechnyx      ['Activision']
#
#                             genre
# 16480              ['Action RPG']
# 16995                 ['Pinball']
# 20765  ['Third-Person Adventure']
# 36351           ['Arcade Racing']

# %%
# Delete null rows
df_clean = df_clean.dropna(subset=['name', 'platform', 'release_date', 'metascore', 'user_score', 'developer', 'publisher', 'genre']).reset_index(drop=True)

# %%
# Delete metascore 'tbd' rows
df_clean = df_clean[df_clean['metascore'] != 'tbd'].reset_index(drop=True)

# %%
# Delete user_score 'tbd' rows
df_clean = df_clean[df_clean['user_score'] != 'tbd'].reset_index(drop=True)

# %%
# Convert name column to string
df_clean["name"] = df_clean["name"].apply(str)

# %%
# Convert metascore and user_score to float
df_clean['metascore'] = pd.to_numeric(df_clean['metascore'], errors='coerce')
df_clean['user_score'] = pd.to_numeric(df_clean['user_score'], errors='coerce')

# %%
# Convertir publisher column to list
import ast

def safe_list(val):
	if isinstance(val, list):
		return val
	if isinstance(val, str) and val.startswith('['):
		try:
			return ast.literal_eval(val)
		except Exception:
			return []
	return [val] if isinstance(val, str) else []

df_clean['publisher'] = df_clean['publisher'].apply(safe_list)

# %%
# Convert release_date to datetime
df_clean['release_date'] = pd.to_datetime(df_clean['release_date'], errors='coerce')

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22224 entries, 0 to 22223
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          22224 non-null  object
#  1   platform      22224 non-null  object
#  2   release_date  22224 non-null  datetime64[ns]
#  3   metascore     22224 non-null  float64
#  4   user_score    22224 non-null  float64
#  5   developer     22224 non-null  object
#  6   publisher     22224 non-null  object
#  7   genre         22224 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Examine column data types

# %%
def count_types(col):
    type_counts = df_clean[col].apply(lambda x: type(x).__name__).value_counts()
    print(f"Data type counts per column '{col}':")
    print(type_counts)

count_types('name')
count_types('platform')
count_types('release_date')
count_types('metascore')
count_types('user_score')
count_types('developer')
count_types('publisher')
count_types('genre')
# Out:
# Data type counts per column 'name':
# name
# str    22224
# Name: count, dtype: int64
# Data type counts per column 'platform':
# platform
# str    22224
# Name: count, dtype: int64
# Data type counts per column 'release_date':
# release_date
# Timestamp    22224
# Name: count, dtype: int64
# Data type counts per column 'metascore':
# metascore
# float    22224
# Name: count, dtype: int64
# Data type counts per column 'user_score':
# user_score
# float    22224
# Name: count, dtype: int64
# Data type counts per column 'developer':
# developer
# str    22224
# Name: count, dtype: int64
# Data type counts per column 'publisher':
# publisher
# list    22224
# Name: count, dtype: int64
# Data type counts per column 'genre':
# genre
# str    22224
# Name: count, dtype: int64

# %% [markdown]
# ### Observe the clean dataset

# %%
df_clean.head(15)
# Out:
#                                        name           platform release_date  \
# 0      The Legend of Zelda: Ocarina of Time        Nintendo 64   1998-11-23
# 1                               SoulCalibur          Dreamcast   1999-09-08
# 2                               SoulCalibur  iOS (iPhone/iPad)   1999-09-08
# 3                               SoulCalibur           Xbox 360   1999-09-08
# 4                       Grand Theft Auto IV      PlayStation 3   2008-04-29
# 5                       Grand Theft Auto IV           Xbox 360   2008-04-29
# 6                       Grand Theft Auto IV                 PC   2008-04-29
# 7                        Super Mario Galaxy                Wii   2007-11-12
# 8                      Super Mario Galaxy 2                Wii   2010-05-23
# 9   The Legend of Zelda: Breath of the Wild              Wii U   2017-03-03
# 10  The Legend of Zelda: Breath of the Wild    Nintendo Switch   2017-03-03
# 11                 Tony Hawk's Pro Skater 3               Xbox   2001-10-30
# 12                 Tony Hawk's Pro Skater 3      PlayStation 2   2001-10-30
# 13                 Tony Hawk's Pro Skater 3           GameCube   2001-10-30
# 14                 Tony Hawk's Pro Skater 3        PlayStation   2001-10-30
#
#     metascore  user_score                developer                 publisher  \
# 0        99.0         9.1                 Nintendo     [Nintendo, Gradiente]
# 1        98.0         7.6                    Namco                   [Namco]
# 2        73.0         7.8                    Namco                   [Namco]
# 3        79.0         7.3                    Namco                   [Namco]
# 4        98.0         8.0           Rockstar North  [Rockstar Games, Capcom]
# 5        98.0         8.3           Rockstar North  [Rockstar Games, Capcom]
# 6        90.0         7.8           Rockstar North  [Rockstar Games, Capcom]
# 7        97.0         9.1                 Nintendo                [Nintendo]
# 8        97.0         9.0       Nintendo EAD Tokyo          [Nintendo, iQue]
# 9        96.0         8.5                 Nintendo                [Nintendo]
# 10       97.0         8.9                 Nintendo                [Nintendo]
# 11       93.0         6.7  Neversoft Entertainment     [Activision, Success]
# 12       97.0         7.6  Neversoft Entertainment     [Activision, Success]
# 13       91.0         7.7  Neversoft Entertainment     [Activision, Success]
# 14       87.0         7.5  Neversoft Entertainment     [Activision, Success]
#
#                     genre
# 0   ['Open-World Action']
# 1         ['3D Fighting']
# 2         ['3D Fighting']
# 3         ['3D Fighting']
# 4   ['Open-World Action']
# 5   ['Open-World Action']
# 6   ['Open-World Action']
# 7       ['3D Platformer']
# 8       ['3D Platformer']
# 9   ['Open-World Action']
# 10  ['Open-World Action']
# 11            ['Skating']
# 12            ['Skating']
# 13            ['Skating']
# 14            ['Skating']

# %%
df_clean.tail(15)
# Out:
#                                                name          platform  \
# 22209                      Fast & Furious: Showdown          Xbox 360
# 22210                       Drake of the 99 Dragons              Xbox
# 22211    Afro Samurai 2: Revenge of Kuma Volume One     PlayStation 4
# 22212     Infestation: Survivor Stories (The War Z)                PC
# 22213                               Deal or No Deal                DS
# 22214                               Deal or No Deal  Game Boy Advance
# 22215               Alone in the Dark: Illumination                PC
# 22216                     Ride to Hell: Retribution                PC
# 22217                     Ride to Hell: Retribution     PlayStation 3
# 22218                     Ride to Hell: Retribution          Xbox 360
# 22219                                  SPOGS Racing               Wii
# 22220       Double Dragon II: Wander of the Dragons          Xbox 360
# 22221                        Vroom in the Night Sky   Nintendo Switch
# 22222                                         Yaris          Xbox 360
# 22223  Family Party: 30 Great Games Obstacle Arcade             Wii U
#
#       release_date  metascore  user_score               developer  \
# 22209   2013-05-21       22.0         1.5         Firebrand Games
# 22210   2003-11-03       22.0         2.0                 Idol FX
# 22211   2015-09-22       21.0         3.0             Versus Evil
# 22212   2012-10-15       20.0         1.7            Fredaikis AB
# 22213   2007-07-23       20.0         3.8        Artefacts Studio
# 22214   2007-07-23       56.0         5.0        Artefacts Studio
# 22215   2015-06-11       19.0         1.3                Pure FPS
# 22216   2013-06-25       16.0         1.4               Eutechnyx
# 22217   2013-06-25       13.0         1.1               Eutechnyx
# 22218   2013-06-25       19.0         1.3               Eutechnyx
# 22219   2008-07-07       18.0         6.3            Pronto Games
# 22220   2013-04-05       17.0         1.6                 Gravity
# 22221   2017-04-05       17.0         3.3                 Poisoft
# 22222   2007-10-10       17.0         5.2  Backbone Entertainment
# 22223   2012-12-04       11.0         2.8           Art Co., Ltd.
#
#                                            publisher                     genre
# 22209                                   [Activision]           ['Auto Racing']
# 22210                                      [Majesco]  ['Third Person Shooter']
# 22211                                  [Versus Evil]        ["3D Beat-'Em-Up"]
# 22212     [Arktos Entertainment, OP Productions LLC]                ['MMORPG']
# 22213  [Destination Software, Mindscape, Koch Media]                ['Trivia']
# 22214  [Destination Software, Mindscape, Koch Media]                ['Trivia']
# 22215                                     [Atari SA]              ['Survival']
# 22216                                  [Deep Silver]      ['Action Adventure']
# 22217                                  [Deep Silver]      ['Action Adventure']
# 22218                                  [Deep Silver]      ['Action Adventure']
# 22219                                    [D2C Games]           ['Auto Racing']
# 22220                                          [CFK]        ["2D Beat-'Em-Up"]
# 22221                                      [Poisoft]                ['Biking']
# 22222                       [Backbone Entertainment]           ['Auto Racing']
# 22223              [D3Publisher, Namco Bandai Games]                 ['Party']

# %% [markdown]
# ### Save the clean dataset

# %%
df_clean.to_csv('metacritic_dataset_clean.csv', index=False)
